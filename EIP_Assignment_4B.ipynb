# %% [markdown]
# <a href="https://colab.research.google.com/github/aswinjayan94/EIP/blob/master/EIP_Assignment_4B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import print_function
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.datasets import cifar10
import numpy as np
import os
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# Training parameters
batch_size = 128  # orig paper trained all networks with batch_size=128
epochs = 50
data_augmentation = True
num_classes = 10

# Subtracting pixel mean improves accuracy
subtract_pixel_mean = True

# %%
# Load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# If subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)

# %%
# Model name, depth and version
model_type = 'ResNet18v1'

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 45:
        lr *= 0.5e-1
    elif epoch > 38:
        lr *= 1e-1
    elif epoch > 30:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder

    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x


def resnet18(input_shape, num_filters=16, num_classes=10):
    """ResNet Version 1 Model builder [a]

    Stacks of 2 x (3 x 3) Conv2D-BN-ReLU
    Last ReLU is after the shortcut connection.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filters is
    doubled. Within each stage, the layers have the same number filters and the
    same number of filters.
    Features maps sizes:
    stage 0: 32x32, num_filters
    stage 1: 16x16, num_filters*2
    stage 2:  8x8,  num_filters*4
    stage 4:  4x4,  num_filters*8

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """

    # 2 resnet blocks in each stage (with 2 resnet layers in each resnet block)
    num_res_blocks = 2

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # Instantiate the stack of residual units
    for stack in range(4):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Add classifier on top.
    # average pool the last layer
    x = AveragePooling2D(pool_size=4)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
model = resnet18(input_shape=input_shape)

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()
print(model_type)

# Prepare model saving directory.
save_dir = os.path.join(os.getcwd(), 'gdrive', 'My Drive', 'cifar10_model_weights')
model_name = 'cifar10_%s_model.{epoch:03d}.h5' % model_type

if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)
# Out:
# Learning rate:  0.001
# Model: "model_8"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_8 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_141 (Conv2D)             (None, 32, 32, 16)   448         input_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_120 (BatchN (None, 32, 32, 16)   64          conv2d_141[0][0]
# __________________________________________________________________________________________________
# activation_120 (Activation)     (None, 32, 32, 16)   0           batch_normalization_120[0][0]
# __________________________________________________________________________________________________
# conv2d_142 (Conv2D)             (None, 32, 32, 16)   2320        activation_120[0][0]
# __________________________________________________________________________________________________
# batch_normalization_121 (BatchN (None, 32, 32, 16)   64          conv2d_142[0][0]
# __________________________________________________________________________________________________
# activation_121 (Activation)     (None, 32, 32, 16)   0           batch_normalization_121[0][0]
# __________________________________________________________________________________________________
# conv2d_143 (Conv2D)             (None, 32, 32, 16)   2320        activation_121[0][0]
# __________________________________________________________________________________________________
# batch_normalization_122 (BatchN (None, 32, 32, 16)   64          conv2d_143[0][0]
# __________________________________________________________________________________________________
# add_57 (Add)                    (None, 32, 32, 16)   0           activation_120[0][0]
#                                                                  batch_normalization_122[0][0]
# __________________________________________________________________________________________________
# activation_122 (Activation)     (None, 32, 32, 16)   0           add_57[0][0]
# __________________________________________________________________________________________________
# conv2d_144 (Conv2D)             (None, 32, 32, 16)   2320        activation_122[0][0]
# __________________________________________________________________________________________________
# batch_normalization_123 (BatchN (None, 32, 32, 16)   64          conv2d_144[0][0]
# __________________________________________________________________________________________________
# activation_123 (Activation)     (None, 32, 32, 16)   0           batch_normalization_123[0][0]
# __________________________________________________________________________________________________
# conv2d_145 (Conv2D)             (None, 32, 32, 16)   2320        activation_123[0][0]
# __________________________________________________________________________________________________
# batch_normalization_124 (BatchN (None, 32, 32, 16)   64          conv2d_145[0][0]
# __________________________________________________________________________________________________
# add_58 (Add)                    (None, 32, 32, 16)   0           activation_122[0][0]
#                                                                  batch_normalization_124[0][0]
# __________________________________________________________________________________________________
# activation_124 (Activation)     (None, 32, 32, 16)   0           add_58[0][0]
# __________________________________________________________________________________________________
# conv2d_146 (Conv2D)             (None, 16, 16, 32)   4640        activation_124[0][0]
# __________________________________________________________________________________________________
# batch_normalization_125 (BatchN (None, 16, 16, 32)   128         conv2d_146[0][0]
# __________________________________________________________________________________________________
# activation_125 (Activation)     (None, 16, 16, 32)   0           batch_normalization_125[0][0]
# __________________________________________________________________________________________________
# conv2d_147 (Conv2D)             (None, 16, 16, 32)   9248        activation_125[0][0]
# __________________________________________________________________________________________________
# conv2d_148 (Conv2D)             (None, 16, 16, 32)   544         activation_124[0][0]
# __________________________________________________________________________________________________
# batch_normalization_126 (BatchN (None, 16, 16, 32)   128         conv2d_147[0][0]
# __________________________________________________________________________________________________
# add_59 (Add)                    (None, 16, 16, 32)   0           conv2d_148[0][0]
#                                                                  batch_normalization_126[0][0]
# __________________________________________________________________________________________________
# activation_126 (Activation)     (None, 16, 16, 32)   0           add_59[0][0]
# __________________________________________________________________________________________________
# conv2d_149 (Conv2D)             (None, 16, 16, 32)   9248        activation_126[0][0]
# __________________________________________________________________________________________________
# batch_normalization_127 (BatchN (None, 16, 16, 32)   128         conv2d_149[0][0]
# __________________________________________________________________________________________________
# activation_127 (Activation)     (None, 16, 16, 32)   0           batch_normalization_127[0][0]
# __________________________________________________________________________________________________
# conv2d_150 (Conv2D)             (None, 16, 16, 32)   9248        activation_127[0][0]
# __________________________________________________________________________________________________
# batch_normalization_128 (BatchN (None, 16, 16, 32)   128         conv2d_150[0][0]
# __________________________________________________________________________________________________
# add_60 (Add)                    (None, 16, 16, 32)   0           activation_126[0][0]
#                                                                  batch_normalization_128[0][0]
# __________________________________________________________________________________________________
# activation_128 (Activation)     (None, 16, 16, 32)   0           add_60[0][0]
# __________________________________________________________________________________________________
# conv2d_151 (Conv2D)             (None, 8, 8, 64)     18496       activation_128[0][0]
# __________________________________________________________________________________________________
# batch_normalization_129 (BatchN (None, 8, 8, 64)     256         conv2d_151[0][0]
# __________________________________________________________________________________________________
# activation_129 (Activation)     (None, 8, 8, 64)     0           batch_normalization_129[0][0]
# __________________________________________________________________________________________________
# conv2d_152 (Conv2D)             (None, 8, 8, 64)     36928       activation_129[0][0]
# __________________________________________________________________________________________________
# conv2d_153 (Conv2D)             (None, 8, 8, 64)     2112        activation_128[0][0]
# __________________________________________________________________________________________________
# batch_normalization_130 (BatchN (None, 8, 8, 64)     256         conv2d_152[0][0]
# __________________________________________________________________________________________________
# add_61 (Add)                    (None, 8, 8, 64)     0           conv2d_153[0][0]
#                                                                  batch_normalization_130[0][0]
# __________________________________________________________________________________________________
# activation_130 (Activation)     (None, 8, 8, 64)     0           add_61[0][0]
# __________________________________________________________________________________________________
# conv2d_154 (Conv2D)             (None, 8, 8, 64)     36928       activation_130[0][0]
# __________________________________________________________________________________________________
# batch_normalization_131 (BatchN (None, 8, 8, 64)     256         conv2d_154[0][0]
# __________________________________________________________________________________________________
# activation_131 (Activation)     (None, 8, 8, 64)     0           batch_normalization_131[0][0]
# __________________________________________________________________________________________________
# conv2d_155 (Conv2D)             (None, 8, 8, 64)     36928       activation_131[0][0]
# __________________________________________________________________________________________________
# batch_normalization_132 (BatchN (None, 8, 8, 64)     256         conv2d_155[0][0]
# __________________________________________________________________________________________________
# add_62 (Add)                    (None, 8, 8, 64)     0           activation_130[0][0]
#                                                                  batch_normalization_132[0][0]
# __________________________________________________________________________________________________
# activation_132 (Activation)     (None, 8, 8, 64)     0           add_62[0][0]
# __________________________________________________________________________________________________
# conv2d_156 (Conv2D)             (None, 4, 4, 128)    73856       activation_132[0][0]
# __________________________________________________________________________________________________
# batch_normalization_133 (BatchN (None, 4, 4, 128)    512         conv2d_156[0][0]
# __________________________________________________________________________________________________
# activation_133 (Activation)     (None, 4, 4, 128)    0           batch_normalization_133[0][0]
# __________________________________________________________________________________________________
# conv2d_157 (Conv2D)             (None, 4, 4, 128)    147584      activation_133[0][0]
# __________________________________________________________________________________________________
# conv2d_158 (Conv2D)             (None, 4, 4, 128)    8320        activation_132[0][0]
# __________________________________________________________________________________________________
# batch_normalization_134 (BatchN (None, 4, 4, 128)    512         conv2d_157[0][0]
# __________________________________________________________________________________________________
# add_63 (Add)                    (None, 4, 4, 128)    0           conv2d_158[0][0]
#                                                                  batch_normalization_134[0][0]
# __________________________________________________________________________________________________
# activation_134 (Activation)     (None, 4, 4, 128)    0           add_63[0][0]
# __________________________________________________________________________________________________
# conv2d_159 (Conv2D)             (None, 4, 4, 128)    147584      activation_134[0][0]
# __________________________________________________________________________________________________
# batch_normalization_135 (BatchN (None, 4, 4, 128)    512         conv2d_159[0][0]
# __________________________________________________________________________________________________
# activation_135 (Activation)     (None, 4, 4, 128)    0           batch_normalization_135[0][0]
# __________________________________________________________________________________________________
# conv2d_160 (Conv2D)             (None, 4, 4, 128)    147584      activation_135[0][0]
# __________________________________________________________________________________________________
# batch_normalization_136 (BatchN (None, 4, 4, 128)    512         conv2d_160[0][0]
# __________________________________________________________________________________________________
# add_64 (Add)                    (None, 4, 4, 128)    0           activation_134[0][0]
#                                                                  batch_normalization_136[0][0]
# __________________________________________________________________________________________________
# activation_136 (Activation)     (None, 4, 4, 128)    0           add_64[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_8 (AveragePoo (None, 1, 1, 128)    0           activation_136[0][0]
# __________________________________________________________________________________________________
# flatten_8 (Flatten)             (None, 128)          0           average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 10)           1290        flatten_8[0][0]
# ==================================================================================================
# Total params: 704,170
# Trainable params: 702,218
# Non-trainable params: 1,952
# __________________________________________________________________________________________________
# ResNet18v1

# %%
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

# %%
def get_random_eraser(p=0.4, s_l=0.02, s_h=0.2, r_1=0.3, r_2=1/0.3, v_l=0, v_h=255, pixel_level=False):
    def eraser(input_img):
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img

        while True:
            s = np.random.uniform(s_l, s_h) * img_h * img_w
            r = np.random.uniform(r_1, r_2)
            w = int(np.sqrt(s / r))
            h = int(np.sqrt(s * r))
            left = np.random.randint(0, img_w)
            top = np.random.randint(0, img_h)

            if left + w <= img_w and top + h <= img_h:
                break

        if pixel_level:
            c = np.random.uniform(v_l, v_h, (h, w, img_c))
        else:
            c = np.random.uniform(v_l, v_h)

        input_img[top:top + h, left:left + w, :] = c

        return input_img

    return eraser

# %%
# Run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.,
        # set range for random channel shifts
        channel_shift_range=0.,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # cutout augmentation
        preprocessing_function=get_random_eraser(v_l=0,v_h=50,pixel_level=False),
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0
        )

    # Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                        validation_data=(x_test, y_test),
                        epochs=epochs, verbose=1, workers=4,
                        callbacks=callbacks)
# Out:
# Using real-time data augmentation.
# Epoch 1/50
# Learning rate:  0.001
# 391/391 [==============================] - 41s 106ms/step - loss: 2.0662 - acc: 0.3260 - val_loss: 1.8957 - val_acc: 0.4129
#
# Epoch 00001: val_acc improved from -inf to 0.41290, saving model to /content/gdrive/My Drive/cifar10_model_weights/cifar10_ResNet18v1_model.001.h5
# Epoch 2/50
# Learning rate:  0.001
# 391/391 [==============================] - 31s 79ms/step - loss: 1.5548 - acc: 0.5116 - val_loss: 1.8648 - val_acc: 0.4798
#
# Epoch 00002: val_acc improved from 0.41290 to 0.47980, saving model to /content/gdrive/My Drive/cifar10_model_weights/cifar10_ResNet18v1_model.002.h5
# Epoch 3/50
# Learning rate:  0.001
# 391/391 [==============================] - 31s 80ms/step - loss: 1.3190 - acc: 0.6002 - val_loss: 1.5713 - val_acc: 0.5359
#
# Epoch 00003: val_acc improved from 0.47980 to 0.53590, saving model to /content/gdrive/My Drive/cifar10_model_weights/cifar10_ResNet18v1_model.003.h5
# Epoch 4/50
# Learning rate:  0.001
# 391/391 [==============================] - 31s 79ms/step - loss: 1.1602 - acc: 0.6590 - val_loss: 1.1865 - val_acc: 0.6546
#
# Epoch 00004: val_acc improved from 0.53590 to 0.65460, saving model to /content/gdrive/My Drive/cifar10_model_weights/cifar10_ResNet18v1_model.004.h5
# Epoch 5/50
# Learning rate:  0.001
# 391/391 [==============================] - 31s 79ms/step - loss: 1.0682 - acc: 0.6930 - val_loss: 1.2105 - val_acc: 0.6567
#
# Epoch 00005: val_acc improved from 0.65460 to 0.65670, saving model to /content/gdrive/My Drive/cifar10_model_weights/cifar10_ResNet18v1_model.005.h5
# Epoch 6/50
# Learning rate:  0.001
# 391/391 [==============================] - 31s 80ms/step - loss: 0.9967 - acc: 0.7208 - val_loss: 1.0747 - val_acc: 0.7040
#
# Epoch 00006: val_acc improved from 0.65670 to 0.70400, saving model to /content/gdrive/My Drive/cifar10_model_weights/cifar10_ResNet18v1_model.006.h5
# Epoch 7/50
# Learning rate:  0.001
# 391/391 [==============================] - 31s 79ms/step - loss: 0.9424 - acc: 0.7383 - val_loss: 1.2654 - val_acc: 0.6570
#
# Epoch 00007: val_acc did not improve from 0.70400
# Epoch 8/50
# Learning rate:  0.001
# 391/391 [==============================] - 31s 80ms/step - loss: 0.8966 - acc: 0.7540 - val_loss: 0.9749 - val_acc: 0.7340
#
# Epoch 00008: val_acc improved from 0.70400 to 0.73400, saving model to /content/gdrive/My Drive/cifar10_model_weights/cifar10_ResNet18v1_model.008.h5
# Epoch 9/50
# Learning rate:  0.001
# 391/391 [==============================] - 31s 80ms/step - loss: 0.8703 - acc: 0.7641 - val_loss: 0.8428 - val_acc: 0.7771
#
# Epoch 00009: val_acc improved from 0.73400 to 0.77710, saving model to /content/gdrive/My Drive/cifar10_model_weights/cifar10_ResNet18v1_model.009.h5
# Epoch 10/50
# Learning rate:  0.001
# 391/391 [==============================] - 31s 79ms/step - loss: 0.8360 - acc: 0.7773 - val_loss: 1.0085 - val_acc: 0.7361
#
# Epoch 00010: val_acc did not improve from 0.77710
# Epoch 11/50
# Learning rate:  0.001
# 391/391 [==============================] - 32s 82ms/step - loss: 0.8063 - acc: 0.7862 - val_loss: 0.9238 - val_acc: 0.7569
#
# Epoch 00011: val_acc did not improve from 0.77710
# Epoch 12/50
# Learning rate:  0.001
# 391/391 [==============================] - 31s 79ms/step - loss: 0.7830 - acc: 0.7934 - val_loss: 0.9155 - val_acc: 0.7572
#
# Epoch 00012: val_acc did not improve from 0.77710
# Epoch 13/50
# Learning rate:  0.001
# 391/391 [==============================] - 31s 79ms/step - loss: 0.7710 - acc: 0.7992 - val_loss: 0.9442 - val_acc: 0.7552
#
# Epoch 00013: val_acc did not improve from 0.77710
# Epoch 14/50
# Learning rate:  0.001
# 391/391 [==============================] - 32s 82ms/step - loss: 0.7463 - acc: 0.8087 - val_loss: 0.7879 - val_acc: 0.7986
#
# Epoch 00014: val_acc improved from 0.77710 to 0.79860, saving model to /content/gdrive/My Drive/cifar10_model_weights/cifar10_ResNet18v1_model.014.h5
# Epoch 15/50
# Learning rate:  0.001
# 391/391 [==============================] - 32s 83ms/step - loss: 0.7273 - acc: 0.8134 - val_loss: 0.8551 - val_acc: 0.7809
#
# Epoch 00015: val_acc did not improve from 0.79860
# Epoch 16/50
# Learning rate:  0.001
# 391/391 [==============================] - 33s 84ms/step - loss: 0.7188 - acc: 0.8172 - val_loss: 0.8565 - val_acc: 0.7809
#
# Epoch 00016: val_acc did not improve from 0.79860
# Epoch 17/50
# Learning rate:  0.001
# 391/391 [==============================] - 32s 82ms/step - loss: 0.7040 - acc: 0.8243 - val_loss: 0.8485 - val_acc: 0.7773
#
# Epoch 00017: val_acc did not improve from 0.79860
# Epoch 18/50
# Learning rate:  0.001
# 391/391 [==============================] - 31s 80ms/step - loss: 0.6902 - acc: 0.8276 - val_loss: 1.0334 - val_acc: 0.7336
#
# Epoch 00018: val_acc did not improve from 0.79860
# Epoch 19/50
# Learning rate:  0.001
# 391/391 [==============================] - 31s 80ms/step - loss: 0.6785 - acc: 0.8334 - val_loss: 1.1153 - val_acc: 0.7310
#
# Epoch 00019: val_acc did not improve from 0.79860
# Epoch 20/50
# Learning rate:  0.001
# 391/391 [==============================] - 31s 80ms/step - loss: 0.6687 - acc: 0.8338 - val_loss: 0.8549 - val_acc: 0.7828
#
# Epoch 00020: val_acc did not improve from 0.79860
# Epoch 21/50
# Learning rate:  0.001
# 391/391 [==============================] - 31s 80ms/step - loss: 0.6581 - acc: 0.8396 - val_loss: 1.2712 - val_acc: 0.6856
#
# Epoch 00021: val_acc did not improve from 0.79860
# Epoch 22/50
# Learning rate:  0.001
# 391/391 [==============================] - 31s 80ms/step - loss: 0.6506 - acc: 0.8425 - val_loss: 0.7311 - val_acc: 0.8151
#
# Epoch 00022: val_acc improved from 0.79860 to 0.81510, saving model to /content/gdrive/My Drive/cifar10_model_weights/cifar10_ResNet18v1_model.022.h5
# Epoch 23/50
# Learning rate:  0.001
# 391/391 [==============================] - 31s 80ms/step - loss: 0.6470 - acc: 0.8445 - val_loss: 1.1537 - val_acc: 0.7113
#
# Epoch 00023: val_acc did not improve from 0.81510
# Epoch 24/50
# Learning rate:  0.001
# 391/391 [==============================] - 31s 80ms/step - loss: 0.6350 - acc: 0.8484 - val_loss: 0.8988 - val_acc: 0.7803
#
# Epoch 00024: val_acc did not improve from 0.81510
# Epoch 25/50
# Learning rate:  0.001
# 391/391 [==============================] - 31s 81ms/step - loss: 0.6306 - acc: 0.8494 - val_loss: 0.7710 - val_acc: 0.8079
#
# Epoch 00025: val_acc did not improve from 0.81510
# Epoch 26/50
# Learning rate:  0.001
# 391/391 [==============================] - 32s 81ms/step - loss: 0.6209 - acc: 0.8528 - val_loss: 0.9568 - val_acc: 0.7623
#
# Epoch 00026: val_acc did not improve from 0.81510
# Epoch 27/50
# Learning rate:  0.001
# 391/391 [==============================] - 32s 81ms/step - loss: 0.6166 - acc: 0.8552 - val_loss: 0.8443 - val_acc: 0.7895
#
# Epoch 00027: val_acc did not improve from 0.81510
# Epoch 28/50
# Learning rate:  0.001
# 391/391 [==============================] - 31s 80ms/step - loss: 0.6136 - acc: 0.8558 - val_loss: 0.8450 - val_acc: 0.7939
#
# Epoch 00028: val_acc did not improve from 0.81510
# Epoch 29/50
# Learning rate:  0.001
# 391/391 [==============================] - 32s 81ms/step - loss: 0.5991 - acc: 0.8596 - val_loss: 0.8605 - val_acc: 0.7896
#
# Epoch 00029: val_acc did not improve from 0.81510
# Epoch 30/50
# Learning rate:  0.001
# 391/391 [==============================] - 32s 81ms/step - loss: 0.6022 - acc: 0.8594 - val_loss: 0.9089 - val_acc: 0.7777
#
# Epoch 00030: val_acc did not improve from 0.81510
# Epoch 31/50
# Learning rate:  0.001
# 391/391 [==============================] - 31s 80ms/step - loss: 0.5927 - acc: 0.8637 - val_loss: 0.7517 - val_acc: 0.8168
#
# Epoch 00031: val_acc improved from 0.81510 to 0.81680, saving model to /content/gdrive/My Drive/cifar10_model_weights/cifar10_ResNet18v1_model.031.h5
# Epoch 32/50
# Learning rate:  0.0001
# 391/391 [==============================] - 32s 81ms/step - loss: 0.5158 - acc: 0.8907 - val_loss: 0.5722 - val_acc: 0.8753
#
# Epoch 00032: val_acc improved from 0.81680 to 0.87530, saving model to /content/gdrive/My Drive/cifar10_model_weights/cifar10_ResNet18v1_model.032.h5
# Epoch 33/50
# Learning rate:  0.0001
# 391/391 [==============================] - 31s 79ms/step - loss: 0.4806 - acc: 0.9035 - val_loss: 0.5659 - val_acc: 0.8778
#
# Epoch 00033: val_acc improved from 0.87530 to 0.87780, saving model to /content/gdrive/My Drive/cifar10_model_weights/cifar10_ResNet18v1_model.033.h5
# Epoch 34/50
# Learning rate:  0.0001
# 391/391 [==============================] - 32s 81ms/step - loss: 0.4731 - acc: 0.9026 - val_loss: 0.5645 - val_acc: 0.8773
#
# Epoch 00034: val_acc did not improve from 0.87780
# Epoch 35/50
# Learning rate:  0.0001
# 391/391 [==============================] - 31s 80ms/step - loss: 0.4554 - acc: 0.9085 - val_loss: 0.5619 - val_acc: 0.8763
#
# Epoch 00035: val_acc did not improve from 0.87780
# Epoch 36/50
# Learning rate:  0.0001
# 391/391 [==============================] - 32s 81ms/step - loss: 0.4461 - acc: 0.9118 - val_loss: 0.5599 - val_acc: 0.8801
#
# Epoch 00036: val_acc improved from 0.87780 to 0.88010, saving model to /content/gdrive/My Drive/cifar10_model_weights/cifar10_ResNet18v1_model.036.h5
# Epoch 37/50
# Learning rate:  0.0001
# 391/391 [==============================] - 31s 80ms/step - loss: 0.4429 - acc: 0.9116 - val_loss: 0.5517 - val_acc: 0.8837
#
# Epoch 00037: val_acc improved from 0.88010 to 0.88370, saving model to /content/gdrive/My Drive/cifar10_model_weights/cifar10_ResNet18v1_model.037.h5
# Epoch 38/50
# Learning rate:  0.0001
# 391/391 [==============================] - 31s 80ms/step - loss: 0.4336 - acc: 0.9144 - val_loss: 0.5454 - val_acc: 0.8831
#
# Epoch 00038: val_acc did not improve from 0.88370
# Epoch 39/50
# Learning rate:  0.0001
# 391/391 [==============================] - 31s 80ms/step - loss: 0.4275 - acc: 0.9168 - val_loss: 0.5533 - val_acc: 0.8788
#
# Epoch 00039: val_acc did not improve from 0.88370
# Epoch 40/50
# Learning rate:  0.0001
# 391/391 [==============================] - 32s 81ms/step - loss: 0.4242 - acc: 0.9162 - val_loss: 0.5407 - val_acc: 0.8845
#
# Epoch 00040: val_acc improved from 0.88370 to 0.88450, saving model to /content/gdrive/My Drive/cifar10_model_weights/cifar10_ResNet18v1_model.040.h5
# Epoch 41/50
# Learning rate:  0.0001
# 391/391 [==============================] - 32s 81ms/step - loss: 0.4172 - acc: 0.9177 - val_loss: 0.5358 - val_acc: 0.8843
#
# Epoch 00041: val_acc did not improve from 0.88450
# Epoch 42/50
# Learning rate:  0.0001
# 391/391 [==============================] - 31s 80ms/step - loss: 0.4089 - acc: 0.9210 - val_loss: 0.5529 - val_acc: 0.8789
#
# Epoch 00042: val_acc did not improve from 0.88450
# Epoch 43/50
# Learning rate:  0.0001
# 391/391 [==============================] - 31s 80ms/step - loss: 0.4034 - acc: 0.9214 - val_loss: 0.5421 - val_acc: 0.8844
#
# Epoch 00043: val_acc did not improve from 0.88450
# Epoch 44/50
# Learning rate:  0.0001
# 391/391 [==============================] - 31s 80ms/step - loss: 0.4013 - acc: 0.9227 - val_loss: 0.5422 - val_acc: 0.8847
#
# Epoch 00044: val_acc improved from 0.88450 to 0.88470, saving model to /content/gdrive/My Drive/cifar10_model_weights/cifar10_ResNet18v1_model.044.h5
# Epoch 45/50
# Learning rate:  0.0001
# 391/391 [==============================] - 31s 80ms/step - loss: 0.3991 - acc: 0.9226 - val_loss: 0.5441 - val_acc: 0.8820
#
# Epoch 00045: val_acc did not improve from 0.88470
# Epoch 46/50
# Learning rate:  0.0001
# 391/391 [==============================] - 31s 80ms/step - loss: 0.3963 - acc: 0.9240 - val_loss: 0.5477 - val_acc: 0.8804
#
# Epoch 00046: val_acc did not improve from 0.88470
# Epoch 47/50
# Learning rate:  5e-05
# 391/391 [==============================] - 31s 80ms/step - loss: 0.3829 - acc: 0.9274 - val_loss: 0.5250 - val_acc: 0.8879
#
# Epoch 00047: val_acc improved from 0.88470 to 0.88790, saving model to /content/gdrive/My Drive/cifar10_model_weights/cifar10_ResNet18v1_model.047.h5
# Epoch 48/50
# Learning rate:  5e-05
# 391/391 [==============================] - 31s 80ms/step - loss: 0.3806 - acc: 0.9278 - val_loss: 0.5248 - val_acc: 0.8901
#
# Epoch 00048: val_acc improved from 0.88790 to 0.89010, saving model to /content/gdrive/My Drive/cifar10_model_weights/cifar10_ResNet18v1_model.048.h5
# Epoch 49/50
# Learning rate:  5e-05
# 391/391 [==============================] - 31s 80ms/step - loss: 0.3731 - acc: 0.9303 - val_loss: 0.5232 - val_acc: 0.8895
#
# Epoch 00049: val_acc did not improve from 0.89010
# Epoch 50/50
# Learning rate:  5e-05
# 391/391 [==============================] - 32s 81ms/step - loss: 0.3763 - acc: 0.9293 - val_loss: 0.5264 - val_acc: 0.8883
#
# Epoch 00050: val_acc did not improve from 0.89010

# %%
# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# 10000/10000 [==============================] - 2s 218us/step
# Test loss: 0.5263574186325073
# Test accuracy: 0.8883

# %% [markdown]
# ## **Grad - CAM**

# %%
from keras.preprocessing import image
import numpy as np
import cv2

# %%
# reload model
model = resnet18(input_shape=input_shape)
model.load_weights('/content/gdrive/My Drive/cifar10_model_weights/cifar10_ResNet18v1_model.048.h5')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4271: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 16)   448         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 16)   64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 16)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 16)   2320        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 16)   64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 16)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 16)   2320        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 16)   64          conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 16)   0           activation_1[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 16)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 16)   2320        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 16)   64          conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 16)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 16)   2320        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 16)   64          conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 32, 16)   0           activation_3[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 16)   0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 32)   4640        activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 16, 32)   128         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 16, 16, 32)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 32)   9248        activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 32)   544         activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 32)   128         conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 16, 16, 32)   0           conv2d_8[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 32)   0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 32)   9248        activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 32)   128         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 32)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 32)   9248        activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 32)   128         conv2d_10[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 16, 16, 32)   0           activation_7[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 32)   0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 8, 8, 64)     18496       activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 8, 8, 64)     256         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 8, 8, 64)     0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 8, 8, 64)     36928       activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 8, 8, 64)     2112        activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 8, 8, 64)     256         conv2d_12[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 8, 8, 64)     0           conv2d_13[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 8, 8, 64)     0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 8, 8, 64)     36928       activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 8, 8, 64)     256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 8, 8, 64)     0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 64)     36928       activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 8, 8, 64)     256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 8, 8, 64)     0           activation_11[0][0]
#                                                                  batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 8, 8, 64)     0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 4, 4, 128)    73856       activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 4, 4, 128)    512         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 4, 4, 128)    0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 4, 4, 128)    147584      activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 4, 4, 128)    8320        activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 4, 4, 128)    512         conv2d_17[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 4, 4, 128)    0           conv2d_18[0][0]
#                                                                  batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 4, 4, 128)    0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 4, 4, 128)    147584      activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 4, 4, 128)    512         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 4, 4, 128)    0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 4, 4, 128)    147584      activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 4, 4, 128)    512         conv2d_20[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 4, 4, 128)    0           activation_15[0][0]
#                                                                  batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 4, 4, 128)    0           add_8[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 1, 1, 128)    0           activation_17[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 128)          0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           1290        flatten_1[0][0]
# ==================================================================================================
# Total params: 704,170
# Trainable params: 702,218
# Non-trainable params: 1,952
# __________________________________________________________________________________________________

# %%
(x_train_orig, y_train_orig), (x_test_orig, y_test_orig) = cifar10.load_data()

# %%
img_indices = [4, 20, 40, 60, 80, 25, 45, 190, 255, 41]
test_idx = [y_test_orig[x][0] for x in img_indices]
outlbl_map = {0: "airplane", 1: "automobile", 2: "bird", 3: "cat", 4: "deer", 5: "dog", 6: "frog", 7: "horse", 8: "ship", 9: "truck"}

for n, i in enumerate(img_indices):
  
  # obtain original image
  img_orig = x_test_orig[i]

  # pre-process
  img = img_orig.astype('float32') / 255
  if subtract_pixel_mean:
      img -= x_train_mean
  img = np.expand_dims(img, axis=0)

  # predict label using model
  preds = model.predict(img)
  class_idx = np.argmax(preds[0])
  class_output = model.output[:, class_idx]
  last_conv_layer = model.get_layer("add_8")

  # original and predicted labels
  class_lbl = outlbl_map[class_idx]
  test_lbl = outlbl_map[test_idx[n]]

  # obtain gradient weighted activations
  grads = K.gradients(class_output, last_conv_layer.output)[0]
  pooled_grads = K.mean(grads, axis=(0, 1, 2))
  iterate = K.function([model.input], [pooled_grads, last_conv_layer.output[0]])

  pooled_grads_value, conv_layer_output_value = iterate([img])

  for i in range(128):
    conv_layer_output_value[:, :, i] *= pooled_grads_value[i]

  # obtain heatmap
  heatmap = np.mean(conv_layer_output_value, axis = -1)
  heatmap = np.maximum(heatmap, 0)
  heatmap /= np.max(heatmap)

  # superimpose heatmap on original image
  heatmap = cv2.resize(heatmap, (img_orig.shape[1], img_orig.shape[0]))
  heatmap = np.uint8(255 * heatmap)
  heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
  superimposed_img = cv2.addWeighted(img_orig, 0.5, heatmap, 0.5, 0)
  from google.colab.patches import cv2_imshow
  print("Actual: {0}, Predicted: {1}".format(test_lbl, class_lbl))
  cv2_imshow( cv2.resize(img_orig, (200, 200)) )
  cv2_imshow( cv2.resize(superimposed_img, (200, 200)) )
  print("\n\n")
# Out:
# Actual: frog, Predicted: frog
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F2935A38C50>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F29359EE2E8>
# Actual: horse, Predicted: horse
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F29359EB828>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F29359EB828>
# Actual: deer, Predicted: deer
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F293597DDD8>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F293597DDD8>
# Actual: horse, Predicted: horse
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F293597DF60>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F2935A38C50>
# Actual: ship, Predicted: ship
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F29359847B8>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F293599F9B0>
# Actual: bird, Predicted: bird
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F293599FD30>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F293599FEF0>
# Actual: truck, Predicted: truck
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F29359ABFD0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F29359A8898>
# Actual: dog, Predicted: dog
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F2935942A58>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F2935948EB8>
# Actual: airplane, Predicted: airplane
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F293594EE48>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F293594EF60>
# Actual: frog, Predicted: frog
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F293596E710>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F29359ABFD0>
